# %%
# !apt-get install -y fonts-nanum > /dev/null
# !fc-cache -fv > /dev/null
# !rm -rf ~/.cache/matplotlib > /dev/null
#런타임 다시시작

# %%
# !pip install konlpy > /dev/null

# %%
from google.colab import files
uploaded= files.upload()
filename= list(uploaded.keys())[0]
filename
# Out:
#      <input type="file" id="files-5448d646-a1ad-4639-ae8e-5a605e16b18f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5448d646-a1ad-4639-ae8e-5a605e16b18f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving e약은요정보검색.xlsx to e약은요정보검색 (1).xlsx
# 'e약은요정보검색.xlsx'

# %%
import numpy as np
import re

# %%
import pandas as pd
raw_df = pd.read_excel(filename)
raw_df.head(1)
# Out:
#       품목일련번호     제품명  ...        공개일자        수정일자
# 0  200300406  닥터베아제정  ...  2020-12-24  2021-01-29
#
# [1 rows x 13 columns]

# %%
raw_df = raw_df[['이 약의 효능은 무엇입니까?']]

# %%
raw_df.to_csv('byong.txt')

# %%
with open('byong.txt') as fp:
  text = fp.read()

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
tokens = okt.nouns(text)

# %%
import nltk
nltk.download('punk')
nltk.download('stopwords')
# Out:
# [nltk_data] Error loading punk: Package 'punk' not found in index
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from collections import Counter

# %%
stopwords ="""
  이 약 효능 무엇 약은 사용합니다 인한 시 사용 증 질환 입 염 의 및
  증상 완화 통 후 등 보급 어깨 눈 피부 임신 유기 치료 병후 불량
  명중 육체 체력 예방 노년기 과 동안 회복 병 수술 감 장애 기
  보조 여러 결핍 골 힘줄 급 퇴 행성 뼈 기 속 이의 입안 입술
  속 인후 코 건 티 위 수족 류마 위산
"""

stop_words = stopwords.split()
new_tokens =[word for word in tokens if word not in stop_words]
token_count = Counter(new_tokens)

# %%
token_count.keys()
# Out:
# dict_keys(['소화', '식욕', '감퇴', '식욕부진', '과식', '체함', '촉진', '위부', '팽', '급성', '상기', '감염', '발열', '해열', '기관지염', '기관지', '천식', '후두', '부비동염', '낭성', '섬유', '객담', '배출', '곤란', '감기', '통증', '요통', '신경통', '류마티스', '타박상', '염좌', '삠', '근육통', '관절통', '진통', '항염', '십이지장', '궤양', '위염', '구역', '구토', '위통', '신트림', '산', '작용', '개선', '만성', '호흡기', '점액', '용해', '거담', '관절염', '관절', '건초염', '상완골', '테니스', '엘', '보우', '외상', '후의', '종창', '두통', '월경', '삔', '치통', '피로', '병중', '저하', '발육', '비타민', '구루병', '각기', '꼬리염', '구내염', '설염', '혀염', '습진', '피부염', '아연', '구강', '내', '살균', '소독', '인두', '발치', '구내', '구취', '공급', '보충', '수', '셀레늄', '환자', '자양', '상처', '화상', '창', '상의', '농양', '부위', '주사', '터', '남성', '성기', '촉각', '예민', '감소', '간질', '환의', '간염', '독성', '코감기', '알레르기', '혈관', '운동', '코염', '재채기', '콧물', '눈물', '환', '간경변', '벌레', '가려
티손', '외', '용제', '병용', '탈모증', '안드로젠', '여성', '사상', '균', '진균', '족부', '백선', '고부', '완선', '체부', '티로스', '포룸', '올비큘라레균', '어루러기', '칸디다증', '베임', '인대', '국', '소형', '안검', '상', '그', '미란', '피부질환', '접촉', '지루', '아토피피부염', '광', '태선', '박탈', '비늘증', '도', '분비물', '화농', '곪음', '비강', '코안', '세척', '안', '충혈', '효모균', '다음', '비듬', '부', '조갑', '손톱', '발톱', '진균증', '투석', '신부전', '질소', '회충', '요충', '십이지장충', '편충', '아메리카', '구충', '분선', '충의', '혼합', '포도', '연쇄', '코리', '륨', '클로스', '트리', '듐', '농가진', '심상', '보통', '모낭', '종기', '한선', '봉', '합창', '식피창', '간반', '피증', '노인성', '반점', '과도', '멜라닌', '점차', '표백', '마', '감수성', '세균', '코르티코이드', '반응', '무좀', '비장', '애로', '식성', '표면', '이하', '곰팡이', '손발톱', '멀미', '어지러움', '겨드랑이', '발의', '다한증', '땀과다증', '조직', '처치', '비대', '켈', '흉터', '피임', '이명증', '분비', '췌장', '효소', '췌장암', '췌담관폐쇄', '췌장염', '절제', '비만증', '태', '지질', '대사', '피부소양증', '타박', '상과', '폴산', '임부', '유부', '수요', '증대', '로부터', '악성', '요법', '항전', '제', '투여', '관여', '알코올중독', '거대', '구성', '부족', '기관지확장증', '폐결핵', '폐기종', '인', '폐', '폐렴', '합병증', '영', '기관', '지경', '폐암', '치골', '때', '안구건조증', '태양', '노출', '화끈', '거리', '안구', '식체', '위체', '정맥', '림프', '다리', '중압감', '결막', '눈병', '수영', '땀', '자외선', '광선', '눈꺼풀', '진무', '름', '하드', '콘택트렌즈', '착용', '눈곱', '살갗', '곳', '추위', '방지', '금연', '제로', '흡연량', '담배', '위해', '니코틴', '의존', '금단증상', '찰', '과상', '봉합', '표', '재성', '고령자', '건피증', '성인', '발뒤꿈치', '복사뼈', '화증', '대퇴부', '사타구니', '변', '토사', '식도', '개월', '담즙', '쓸개즙', '부전', '쓸 ...

# %%
df = pd.DataFrame(columns=['증상', '개수'])
df['증상']= token_count.keys()
df['개수']= token_count.values()

# %%
df_count = df.sort_values(by='개수',ascending=False).head(100)
df_count.reset_index(drop=True)
# Out:
#       증상    개수
# 0     통증  1151
# 1    근육통  1149
# 2    관절염   921
# 3     피로   920
# 4    관절통   862
# ..   ...   ...
# 95    건염   155
# 96   상완골   154
# 97    보우   151
# 98    화상   150
# 99  십이지장   148
#
# [100 rows x 2 columns]

# %%
df_count.to_csv('count.csv')

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
wordcloud = WordCloud(font_path=path,
                      background_color='white',
                      max_words=100,
                      relative_scaling=0.3,
                      width=800, height=400
                      ).generate_from_frequencies(token_count)
plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
